# %%
from pyspark.sql import SparkSession

# Initialize Spark Session
spark = SparkSession.builder \
    .appName("Skills Demand Analytics") \
    .getOrCreate()

print("Spark Session created!")
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/ubuntu/venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/venv/lib/python3.12/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       1 from pyspark.sql import SparkSession
#       3 # Initialize Spark Session
#       4 spark = SparkSession.builder \
#       5     .appName("Skills Demand Analytics") \
# ----> 6     .getOrCreate()
#       8 print("Spark Session created!")
#
# File ~/venv/lib/python3.12/site-packages/pyspark/sql/session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File ~/venv/lib/python3.12/site-packages/pyspark/context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# --> 515         SparkContext(conf=conf or SparkConf())
#     516     assert SparkContext._active_spark_context is not None
#     517     return SparkContext._active_spark_context
#
# File ~/venv/lib/python3.12/site-packages/pyspark/context.py:203, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     201 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     202 try:
# --> 203     self._do_init(
#     204         master,
#     205         appName,
#     206         sparkHome,
#     207         pyFiles,
#     208         environment,
#     209         batchSize,
#     210         serializer,
#     211         conf,
#     212         jsc,
#     213         profiler_cls,
#     214         udf_profiler_cls,
#     215         memory_profiler_cls,
#     216     )
#     217 except BaseException:
#     218     # If an error occurs, clean up in order to allow future SparkContext creation:
#     219     self.stop()
#
# File ~/venv/lib/python3.12/site-packages/pyspark/context.py:296, in SparkContext._do_init(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     293 self.environment["PYTHONHASHSEED"] = os.environ.get("PYTHONHASHSEED", "0")
#     295 # Create the Java SparkContext through Py4J
# --> 296 self._jsc = jsc or self._initialize_context(self._conf._jconf)
#     297 # Reset the SparkConf to the one actually used by the SparkContext in JVM.
#     298 self._conf = SparkConf(_jconf=self._jsc.sc().conf())
#
# File ~/venv/lib/python3.12/site-packages/pyspark/context.py:421, in SparkContext._initialize_context(self, jconf)
#     417 """
#     418 Initialize SparkContext in function to allow subclass specific initialization
#     419 """
#     420 assert self._jvm is not None
# --> 421 return self._jvm.JavaSparkContext(jconf)
#
# File ~/venv/lib/python3.12/site-packages/py4j/java_gateway.py:1586, in JavaClass.__call__(self, *args)
#    1578 args_command = "".join(
#    1579     [get_command_part(arg, self._pool) for arg in new_args])
#    1581 command = proto.CONSTRUCTOR_COMMAND_NAME +\
#    1582     self._command_header +\
#    1583     args_command +\
#    1584     proto.END_COMMAND_PART
# -> 1586 answer = self._gateway_client.send_command(command)
#    1587 return_value = get_return_value(
#    1588     answer, self._gateway_client, None, self._fqn)
#    1590 for temp_arg in temp_args:
#
# File ~/venv/lib/python3.12/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/venv/lib/python3.12/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Load raw data
data_path = "hdfs://namenode:9000/user/ubuntu/Project_Code/cleaned_job_data_using_spark.csv"

raw_data = spark.sparkContext.textFile(data_path)
# Remove header
header = raw_data.first()
parsed_data = raw_data.filter(lambda row: row != header)

print("First 5 rows of raw data (excluding header):")
print(parsed_data.take(5))
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# First 5 rows of raw data (excluding header):
# ['"family lawyer","child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules","child custody law family law legal advocacy negotiation court representation legal research client counseling case preparation","electronics instrumentation","port moresby papua new guinea","2 to 10 years","65000","89000"', '"ux ui designer","interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs","interaction design principles user behavior and psychology wireframinimumg and prototyping tools animation and micro interaction design collaborative design processes","pharmaceuticals","moscow russia","2 to 13 years","57000","118000"', '"executive assistant","project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met","project management communication time management organization problem solving","minimuming crude oil production","djibouti city djibouti","3 to 9 years","64000","107000"', '"legal advisor","as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings","legal counsel legal advice contract negotiation legal research litigation support client representation legal writing regulatory compliance","real estate","libreville gabon","4 to 14 years","63000","128000"', '"pediatrician","pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients","pediatric surgery surgical procedures for children operating room protocols patient care surgical techniques pediatric anesthesia","computer software","oranjestad aruba","0 to 11 years","57000","89000"']

# %%
# Parse and Clean Data

import csv
from io import StringIO

def parse_csv(row):
    f = StringIO(row)
    reader = csv.reader(f, skipinitialspace=True)
    return next(reader)

# Parse rows using csv module
parsed_data = parsed_data.map(parse_csv)

# Extract relevant fields
def extract_relevant_fields(row):
    try:
        return [
            row[1],  # job_description
            row[2],  # job_skills
            row[3],  # job_industry
            row[4],  # job_location
            row[5],  # experience_level
            float(row[6]) if row[6] else None,  # min_salary
            float(row[7]) if row[7] else None   # max_salary
        ]
    except Exception as e:
        print(f"Error processing row: {row} -> {e}")
        return None

cleaned_data = parsed_data.map(extract_relevant_fields).filter(lambda row: row is not None)

print("First 5 rows of cleaned data:")
print(cleaned_data.take(5))
# Out:
# First 5 rows of cleaned data:
# [['child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules', 'child custody law family law legal advocacy negotiation court representation legal research client counseling case preparation', 'electronics instrumentation', 'port moresby papua new guinea', '2 to 10 years', 65000.0, 89000.0], ['interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs', 'interaction design principles user behavior and psychology wireframinimumg and prototyping tools animation and micro interaction design collaborative design processes', 'pharmaceuticals', 'moscow russia', '2 to 13 years', 57000.0, 118000.0], ['project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met', 'project management communication time management organization problem solving', 'minimuming crude oil production', 'djibouti city djibouti', '3 to 9 years', 64000.0, 107000.0], ['as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings', 'legal counsel legal advice contract negotiation legal research litigation support client representation legal writing regulatory compliance', 'real estate', 'libreville gabon', '4 to 14 years', 63000.0, 128000.0], ['pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients', 'pediatric surgery surgical procedures for children operating room protocols patient care surgical techniques pediatric anesthesia', 'computer software', 'oranjestad aruba', '0 to 11 years', 57000.0, 89000.0]]

# %%
# Convert the cleaned RDD into a DataFrame for further processing.

columns = ["job_description", "job_skills", "job_industry", "job_location", "experience_level", "min_salary", "max_salary"]
cleaned_df = spark.createDataFrame(cleaned_data, schema=columns)

print("DataFrame schema:")
cleaned_df.printSchema()

print("First 5 rows of DataFrame:")
cleaned_df.show(5, truncate=False)
# Out:
# DataFrame schema:
# root
#  |-- job_description: string (nullable = true)
#  |-- job_skills: string (nullable = true)
#  |-- job_industry: string (nullable = true)
#  |-- job_location: string (nullable = true)
#  |-- experience_level: string (nullable = true)
#  |-- min_salary: double (nullable = true)
#  |-- max_salary: double (nullable = true)
#
# First 5 rows of DataFrame:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+-----------------------------+----------------+----------+----------+
# |job_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |job_skills                                                                                                                                                            |job_industry                   |job_location                 |experience_level|min_salary|max_salary|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+-----------------------------+----------------+----------+----------+
# |child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules                                                                                                                                    |child custody law family law legal advocacy negotiation court representation legal research client counseling case preparation                                        |electronics instrumentation    |port moresby papua new guinea|2 to 10 years   |65000.0   |89000.0   |
# |interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs                                                                                                                               |interaction design principles user behavior and psychology wireframinimumg and prototyping tools animation and micro interaction design collaborative design processes|pharmaceuticals                |moscow russia                |2 to 13 years   |57000.0   |118000.0  |
# |project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met                                                                                                                                                                              |project management communication time management organization problem solving                                                                                         |minimuming crude oil production|djibouti city djibouti       |3 to 9 years    |64000.0   |107000.0  |
# |as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings|legal counsel legal advice contract negotiation legal research litigation support client representation legal writing regulatory compliance                           |real estate                    |libreville gabon             |4 to 14 years   |63000.0   |128000.0  |
# |pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients                                                                                                                     |pediatric surgery surgical procedures for children operating room protocols patient care surgical techniques pediatric anesthesia                                     |computer software              |oranjestad aruba             |0 to 11 years   |57000.0   |89000.0   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+-----------------------------+----------------+----------+----------+
# only showing top 5 rows

# %%
# We use Tokenizer to split job descriptions into words.

from pyspark.ml.feature import Tokenizer

tokenizer = Tokenizer(inputCol="job_description", outputCol="words")
tokenized_data = tokenizer.transform(cleaned_df)

print("First 5 rows after tokenization:")
tokenized_data.select("job_description", "words").show(5, truncate=False)
# Out:
# First 5 rows after tokenization:
# [Stage 5:>                                                          (0 + 1) / 1]
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |job_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |words                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules                                                                                                                                    |[child, custody, lawyers, specialize, in, family, law, focusing, on, cases, related, to, child, custody, and, visitation, rights, they, represent, clients, in, court, provide, legal, counsel, and, advocate, for, the, best, interests, of, children, in, custody, disputes, what, you, ll, do, specialize, in, child, custody, cases, advocating, for, the, best, interests, of, children, conduct, investigations, gather, evidence, and, present, cases, in, court, negotiate, parenting, plans, and, visitation, schedules]                                                                                                                                                    |
# |interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs                                                                                                                               |[interaction, designers, specialize, in, designing, user, interactions, within, digital, interfaces, they, create, meaningful, and, engaging, user, experienceeriences, by, considering, user, behaviors, and, system, responses, what, you, ll, do, work, on, interaction, design, defining, how, users, interact, with, digital, products, and, ensuring, a, seamless, user, journey, create, wireframes, and, prototypes, to, illustrate, interactions, collaborate, with, developers, to, implement, interaction, designs]                                                                                                                                                       |
# |project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met                                                                                                                                                                              |[project, coordinators, assist, in, planning, executing, and, monitoring, projects, they, facilitate, communication, among, team, members, track, project, progress, and, ensure, tasks, are, completed, on, time, what, you, ll, do, assist, in, project, management, activities, such, as, project, planning, scheduling, and, documentation, coordinate, project, meetings, and, communicate, project, updates, to, stakeholders, ensure, project, milestones, are, met]                                                                                                                                                                                                          |
# |as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings|[as, a, legal, counsel, your, responsibilities, include, providing, legal, advice, drafting, contracts, and, ensuring, compliance, with, laws, and, regulations, you, will, represent, the, company, in, legal, matters, negotiate, agreements, and, mitigate, legal, risks, your, role, involves, staying, informed, about, changes, in, the, law, and, advising, management, on, legal, issues, affecting, the, business, what, you, ll, do, provide, legal, advice, and, counsel, to, individuals, businesses, or, organizations, on, various, legal, matters, draft, legal, documents, contracts, and, agreements, represent, clients, in, negotiations, and, legal, proceedings]|
# |pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients                                                                                                                     |[pediatric, surgeons, specialize, in, performinimumg, surgical, procedures, on, children, including, infants, and, adolescents, they, diagnose, surgical, conditions, perform, surgeries, and, collaborate, with, other, healthcare, professionals, to, ensure, the, best, outcomes, what, you, ll, do, perform, surgical, procedures, on, pediatric, patients, including, congenital, abnormalities, and, injuries, coordinate, pre, operative, and, post, operative, care, ensure, the, well, being, and, recovery, of, young, patients]                                                                                                                                           |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Calculate the Term Frequency-Inverse Document Frequency (TF-IDF) for the tokenized job descriptions.

from pyspark.ml.feature import HashingTF, IDF

# Compute term frequencies
hashing_tf = HashingTF(inputCol="words", outputCol="raw_features", numFeatures=1000)
tf_data = hashing_tf.transform(tokenized_data)

# Compute IDF
idf = IDF(inputCol="raw_features", outputCol="features")
idf_model = idf.fit(tf_data)
tfidf_data = idf_model.transform(tf_data)

print("First 5 rows after TF-IDF:")
tfidf_data.select("job_description", "features").show(5, truncate=False)
# Out:
# [Stage 6:==============>                                            (2 + 2) / 8]
# 11:16:04.816 [dispatcher-CoarseGrainedScheduler] ERROR org.apache.spark.scheduler.cluster.YarnScheduler - Lost executor 1 on datanode3: Container marked as failed: container_1731663000200_0012_01_000002 on host: datanode3. Exit status: -100. Diagnostics: Container released on a *lost* node.
# First 5 rows after TF-IDF:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |job_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules                                                                                                                                    |(1000,[17,32,48,54,69,78,92,130,192,226,244,250,285,297,338,344,353,359,361,375,443,447,471,488,495,504,525,526,568,653,663,703,717,736,753,763,793,854,891,901,906,940,946,979],[2.1846495909025325,1.5194266315241676,0.5366735394555917,4.74565334697437,4.192418195089488,14.96413911877205,3.7017528006397935,6.154277645552479,1.642053875774854,0.0,13.055426680910832,3.3034410482422936,1.9522805456759895,4.345227235999641,0.0,1.9563483110482238,2.380324650111367,3.7545239322468293,5.6928618999321055,6.751537779986654,0.0,2.151755248299781,3.0489611084329935,0.30705179604012167,2.759654622518771,2.084499157108454,6.8749926126597405,0.0,4.577659558011263,3.7503946482090633,4.639779711235581,9.746076170229168,3.941679306392814,1.0616471069544104,4.061118865889413,5.552508500771513,3.0106824271289634,3.940784165668081,0.0,4.199470788609428,3.0013842367035006,2.642806378236576,1.2656509053861362,3.6534696433390925])                                                                                                                                                                                                                                                       |
# |interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs                                                                                                                               |(1000,[25,48,92,128,167,173,182,187,226,323,324,338,370,384,398,404,427,441,443,467,488,501,526,527,577,581,613,643,647,648,650,663,676,678,705,716,731,736,817,872,882,891,918,922,996],[3.1496983321626137,0.5366735394555917,1.8508764003198968,1.7636647687955453,3.754921878847648,3.152251278138687,1.8376629524091301,9.760650396630549,0.0,3.3146198537920752,1.5067857424850588,0.0,7.013268147708337,4.206823610187705,2.7141987653553845,2.978084340337386,3.198898558955658,2.532539727219,0.0,1.0540066967103925,0.6141035920802433,4.417082320616495,0.0,1.9547333523018877,2.432971467408347,2.8838676900560225,2.338259594991023,2.887684042676599,1.173492007645189,2.534926241812016,1.2010392388348385,0.9279559422471163,2.6845759978992487,2.0474564329099696,2.92565120819993,2.742014366723408,5.558220736019939,1.0616471069544104,2.649047726945996,1.8508526838737263,8.536847841162157,0.0,3.952516296443787,1.528783391590324,3.057960932343063])                                                                                                                                                                                                                                  |
# |project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met                                                                                                                                                                              |(1000,[10,48,63,71,117,157,163,213,226,230,241,272,338,362,381,443,450,468,482,488,526,577,588,589,590,592,619,663,680,736,749,763,801,836,870,891,910,913,970,980],[4.235686387797373,0.5366735394555917,3.64978428247804,3.2520725763322798,3.3159704314119542,4.3518436733215085,4.533619663663626,3.834420765835964,0.0,22.43513617741009,1.0731184171057546,2.6149506703607046,0.0,4.061587511691894,4.768494961648533,0.0,3.156938945950214,2.3137038604143005,2.7752774541993275,0.30705179604012167,0.0,2.432971467408347,5.464351079692576,2.6446318577133785,3.104119747908837,3.2546275538998266,3.098075515669658,1.8559118844942326,2.238628727575119,1.0616471069544104,2.1531393685490783,5.552508500771513,4.7539056990705895,3.651816730603051,2.2709464695669843,0.0,3.574729814547423,2.478298938894441,4.6793785229051075,3.148106044288014])                                                                                                                                                                                                                                                                                                                                              |
# |as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings|(1000,[17,49,58,93,128,142,158,189,201,226,229,241,263,279,285,338,346,350,354,362,373,374,392,406,420,443,447,462,467,471,488,524,526,545,568,611,647,650,663,682,685,717,736,741,749,753,872,891,942,943,946,953,956,970,979],[3.276974386353799,6.494603027615508,3.8301204237826485,5.0366520929111696,1.7636647687955453,3.247109866438326,2.214351751903713,3.8407037504497628,5.032073679724653,0.0,7.152697562404289,1.0731184171057546,4.541904971995715,3.938645468819041,1.9522805456759895,0.0,9.499183257063239,3.495231019288413,4.530733325574826,4.061587511691894,4.189422522208836,2.506710538062746,5.435874775277795,3.2477168758176873,3.141690266915727,0.0,2.151755248299781,3.091807794382417,1.0540066967103925,27.440649975896942,0.30705179604012167,3.305588949791082,0.0,4.19319936482805,2.2888297790056313,1.9213495565890235,1.173492007645189,0.6005196194174193,4.639779711235581,3.5699326880396764,3.942863401258742,7.883358612785628,2.123294213908821,1.6850085512658548,2.1531393685490783,8.122237731778826,1.8508526838737263,0.0,1.9509690127433894,3.83752850314381,1.2656509053861362,3.3069782389358084,4.533850931009708,2.3396892614525537,3.6534696433390925])|
# |pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients                                                                                                                     |(1000,[17,48,53,73,92,98,142,157,226,263,289,310,329,334,338,349,361,443,488,495,511,526,527,533,540,605,610,611,647,650,661,663,678,680,683,736,763,809,855,870,881,891,962,973],[2.1846495909025325,0.5366735394555917,3.5037401346329067,3.7449678698751123,1.8508764003198968,5.22676373932488,3.247109866438326,2.1759218366607542,0.0,2.2709524859978574,3.3108002566851784,2.0464080837233256,4.754770751027648,2.9215625976719,0.0,5.2280181892727695,2.8464309499660527,0.0,0.30705179604012167,1.3798273112593855,9.597334878172145,0.0,1.9547333523018877,2.648793109814156,3.497648954157674,3.5040910951328086,5.54502344719431,1.9213495565890235,1.173492007645189,0.6005196194174193,3.941167699295897,1.8559118844942326,2.0474564329099696,2.238628727575119,5.7734961563498395,2.123294213908821,2.7762542503857564,2.741513393669134,3.939921752454843,2.2709464695669843,8.37892699651668,0.0,6.869629386109997,4.194804732863777])                                                                                                                                                                                                                                                       |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Apply K-Means Clustering: Group job descriptions into clusters based on their TF-IDF features.

from pyspark.ml.clustering import KMeans

kmeans = KMeans(featuresCol="features", predictionCol="cluster", k=5, seed=42)
model = kmeans.fit(tfidf_data)
clustered_data = model.transform(tfidf_data)

print("First 5 rows after clustering:")
clustered_data.select("job_description", "cluster").show(5, truncate=False)
# Out:
# First 5 rows after clustering:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |job_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |cluster|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |child custody lawyers specialize in family law focusing on cases related to child custody and visitation rights they represent clients in court provide legal counsel and advocate for the best interests of children in custody disputes what you ll do specialize in child custody cases advocating for the best interests of children conduct investigations gather evidence and present cases in court negotiate parenting plans and visitation schedules                                                                                                                                    |1      |
# |interaction designers specialize in designing user interactions within digital interfaces they create meaningful and engaging user experienceeriences by considering user behaviors and system responses what you ll do work on interaction design defining how users interact with digital products and ensuring a seamless user journey create wireframes and prototypes to illustrate interactions collaborate with developers to implement interaction designs                                                                                                                               |1      |
# |project coordinators assist in planning executing and monitoring projects they facilitate communication among team members track project progress and ensure tasks are completed on time what you ll do assist in project management activities such as project planning scheduling and documentation coordinate project meetings and communicate project updates to stakeholders ensure project milestones are met                                                                                                                                                                              |1      |
# |as a legal counsel your responsibilities include providing legal advice drafting contracts and ensuring compliance with laws and regulations you will represent the company in legal matters negotiate agreements and mitigate legal risks your role involves staying informed about changes in the law and advising management on legal issues affecting the business what you ll do provide legal advice and counsel to individuals businesses or organizations on various legal matters draft legal documents contracts and agreements represent clients in negotiations and legal proceedings|1      |
# |pediatric surgeons specialize in performinimumg surgical procedures on children including infants and adolescents they diagnose surgical conditions perform surgeries and collaborate with other healthcare professionals to ensure the best outcomes what you ll do perform surgical procedures on pediatric patients including congenital abnormalities and injuries coordinate pre operative and post operative care ensure the well being and recovery of young patients                                                                                                                     |1      |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# only showing top 5 rows

# %%
# Analyze High-Demand Skills : aggregate the data to identify high-demand skills by industry and cluster.

# Group by job industry and cluster to count jobs
high_demand_skills = clustered_data.groupBy("job_industry", "cluster") \
    .count() \
    .orderBy("count", ascending=False)

print("High-demand skills by industry:")
high_demand_skills.show(1000, truncate=False)
# Out:
# High-demand skills by industry:
# [Stage 38:==================================================>       (7 + 1) / 8]
# +----------------------------------------------+-------+-----+
# |job_industry                                  |cluster|count|
# +----------------------------------------------+-------+-----+
# |pharmaceuticals                               |1      |52752|
# |chemicals                                     |1      |49133|
# |utilities gas and electric                    |1      |40549|
# |telecommunications                            |1      |38772|
# |commercial banks                              |1      |37122|
# |specialty retailers other                     |1      |33732|
# |financial services                            |1      |31599|
# |automotive                                    |1      |31590|
# |minimuming crude oil production               |1      |28305|
# |insurance property and casualty stock         |1      |28204|
# |minimuming                                    |1      |26400|
# |semiconductors and other electronic components|1      |24756|
# |real estate                                   |1      |24501|
# |internet services and retailing               |1      |22849|
# |insurance life health stock                   |1      |21190|
# |information technology services               |1      |21151|
# |banking financial services                    |1      |21136|
# |wholesalers diversified                       |1      |19522|
# |pipelines                                     |1      |19493|
# |diversified financials                        |1      |19456|
# |food consumer products                        |1      |19437|
# |automotive retailing services                 |1      |17721|
# |motor vehicles parts                          |1      |17639|
# |insurance                                     |1      |17624|
# |packaging containers                          |1      |15894|
# |entertainment                                 |1      |15823|
# |securities                                    |1      |15817|
# |aerospace defense                             |1      |15704|
# |petroleum refining                            |1      |15677|
# |industrial machinery                          |1      |15641|
# |metals                                        |1      |14149|
# |insurance life health mutual                  |1      |14143|
# |banking and financial services                |1      |14096|
# |financial data services                       |1      |13815|
# |airlines                                      |1      |12550|
# |general merchandisers                         |1      |12498|
# |energy                                        |1      |12425|
# |retail                                        |1      |12395|
# |healthcare                                    |1      |12320|
# |food services                                 |1      |12291|
# |computer software                             |1      |12260|
# |food production                               |1      |12248|
# |banking                                       |1      |12111|
# |specialty retailers apparel                   |1      |10695|
# |computers office equipment                    |1      |10634|
# |utilities                                     |1      |10615|
# |medical products and equipment                |1      |10578|
# |homebuilders                                  |1      |10538|
# |engineering construction                      |1      |10501|
# |oil and gas                                   |1      |10495|
# |consumer goods                                |1      |10482|
# |financial services investment                 |1      |10454|
# |beverages                                     |1      |10435|
# |information technology and services           |1      |8941 |
# |energy oil gas experienceloration production  |1      |8935 |
# |transportation and logistics                  |1      |8899 |
# |health care medical facilities                |1      |8885 |
# |health care insurance and managed care        |1      |8874 |
# |electrical equipment                          |1      |8814 |
# |oil gas                                       |1      |8800 |
# |wholesalers health care                       |1      |8781 |
# |building materials glass                      |1      |8780 |
# |food and beverage                             |1      |8764 |
# |insurance property and casualty mutual        |1      |8753 |
# |wholesalers food and grocery                  |1      |8719 |
# |health care pharmacy and other services       |1      |8710 |
# |food and drug stores                          |1      |8573 |
# |conglomerate                                  |1      |8573 |
# |construction and farm machinery               |1      |7142 |
# |real estate construction                      |1      |7128 |
# |network and other communications equipment    |1      |7098 |
# |apparel                                       |1      |7089 |
# |airlines aviation                             |1      |7083 |
# |distribution wholesale                        |1      |7073 |
# |home equipment furnishings                    |1      |7064 |
# |tobacco                                       |1      |7033 |
# |diversified outsourcing services              |1      |7016 |
# |e commerce technology                         |1      |7011 |
# |hotels casinos resorts                        |1      |6943 |
# |aerospace and defense                         |1      |6941 |
# |electronics electrical equip                  |1      |6864 |
# |electronics appliances                        |1      |5469 |
# |transportation logistics                      |1      |5405 |
# |industrial manufacturing                      |1      |5395 |
# |trucking truck leasing                        |1      |5378 |
# |engineering industrial equipment              |1      |5349 |
# |real estate reit                              |1      |5342 |
# |information technology                        |1      |5337 |
# |food manufacturing                            |1      |5332 |
# |wholesalers electronics and office equipment  |1      |5331 |
# |household and personal products               |1      |5277 |
# |energy utilities                              |1      |5255 |
# |railroads                                     |1      |5171 |
# |travel and leisure cruises                    |1      |5127 |
# |travel and leisure hotels                     |1      |3656 |
# |cement and building materials                 |1      |3623 |
# |advertising marketing                         |1      |3608 |
# |hospitality hotels                            |1      |3595 |
# |construction engineering                      |1      |3595 |
# |temporary help                                |1      |3592 |
# |software                                      |1      |3584 |
# |retail food drug                              |1      |3553 |
# |oil and gas equipment services                |1      |3549 |
# |media entertainment                           |1      |3543 |
# |scientific photographic and control equipment |1      |3539 |
# |media and entertainment                       |1      |3538 |
# |steel                                         |1      |3535 |
# |waste management                              |1      |3535 |
# |technology telecommunications                 |1      |3529 |
# |manufacturing diversified                     |1      |3507 |
# |retail apparel                                |1      |3506 |
# |transportation infrastructure                 |1      |3500 |
# |consumer products cosmetics                   |1      |3491 |
# |mail package and freight delivery             |1      |3479 |
# |industrial conglomerate                       |1      |3449 |
# |technology                                    |1      |3444 |
# |technology entertainment                      |1      |3428 |
# |restaurants                                   |1      |3427 |
# |logistics delivery services                   |1      |3419 |
# |paints and coatings                           |1      |3415 |
# |retail home improvement                       |1      |3406 |
# |electronics                                   |1      |1861 |
# |manufacturing electrical equipment            |1      |1832 |
# |building materials construction               |1      |1822 |
# |technology search engines                     |1      |1814 |
# |forest and paper products                     |1      |1813 |
# |equipment rental                              |1      |1808 |
# |financial technology fintech                  |1      |1805 |
# |technology social media                       |1      |1803 |
# |construction building materials               |1      |1803 |
# |agrochemicals                                 |1      |1801 |
# |financial services investment management      |1      |1801 |
# |electronics components                        |1      |1793 |
# |equipment leasing                             |1      |1791 |
# |gaminimumg gambling                           |1      |1789 |
# |financial services insurance                  |1      |1789 |
# |apparel and textiles                          |1      |1788 |
# |hospitality entertainment                     |1      |1788 |
# |electronics instrumentation                   |1      |1787 |
# |retail discount department stores             |1      |1787 |
# |cement and concrete                           |1      |1781 |
# |business services testing compliance          |1      |1781 |
# |personal care cosmetics                       |1      |1781 |
# |ports and infrastructure                      |1      |1780 |
# |retail farm and ranch supplies                |1      |1778 |
# |aviation airlines                             |1      |1778 |
# |retail general merchandise                    |1      |1777 |
# |jewelry and watches                           |1      |1777 |
# |logistics                                     |1      |1775 |
# |consumer products cleaning products           |1      |1773 |
# |internet technology                           |1      |1772 |
# |financial services investment banking         |1      |1771 |
# |technology electronics                        |1      |1769 |
# |apparel footwear                              |1      |1768 |
# |aluminimumum and copper manufacturing         |1      |1768 |
# |entertainment satellite radio                 |1      |1766 |
# |food beverage                                 |1      |1766 |
# |cloud software and services                   |1      |1763 |
# |construction                                  |1      |1762 |
# |entertainment music streaminimumg             |1      |1760 |
# |postal services                               |1      |1760 |
# |semiconductors                                |1      |1757 |
# |retail books news                             |1      |1756 |
# |technology ride hailing                       |1      |1754 |
# |retail electronics                            |1      |1754 |
# |insurance property casualty                   |1      |1754 |
# |medical devices healthcare                    |1      |1753 |
# |manufacturing transportation                  |1      |1753 |
# |gas and energy                                |1      |1752 |
# |beverage                                      |1      |1748 |
# |business services pest control                |1      |1747 |
# |apparel fashion                               |1      |1745 |
# |manufacturing steel                           |1      |1745 |
# |online recruitment                            |1      |1744 |
# |gambling gaminimumg                           |1      |1744 |
# |construction and engineering                  |1      |1743 |
# |diversified                                   |1      |1741 |
# |advertising and marketing                     |1      |1741 |
# |publishing printing                           |1      |1738 |
# |energy diversified                            |1      |1738 |
# |transportation equipment                      |1      |1737 |
# |e commerce                                    |1      |1733 |
# |gambling                                      |1      |1733 |
# |transportation airlines                       |1      |1731 |
# |energy coal                                   |1      |1729 |
# |software technology                           |1      |1727 |
# |transportation                                |1      |1727 |
# |renewable energy                              |1      |1719 |
# |tire manufacturing                            |1      |1717 |
# |education                                     |1      |1715 |
# |entertainment streaminimumg services          |1      |1713 |
# |technology security                           |1      |1712 |
# |lighting electronics                          |1      |1710 |
# |transportation rail                           |1      |1706 |
# |business services data analytics              |1      |1701 |
# |energy oil gas services                       |1      |1700 |
# |life sciences                                 |1      |1698 |
# |cement and chemicals                          |1      |1697 |
# |food and beverage alcoholic beverages         |1      |1691 |
# |manufacturing building systems                |1      |1683 |
# |pharmaceuticals                               |3      |611  |
# |pharmaceuticals                               |2      |572  |
# |chemicals                                     |2      |570  |
# |chemicals                                     |3      |522  |
# |utilities gas and electric                    |2      |458  |
# |utilities gas and electric                    |3      |449  |
# |commercial banks                              |3      |438  |
# |telecommunications                            |2      |430  |
# |telecommunications                            |3      |412  |
# |commercial banks                              |2      |397  |
# |financial services                            |2      |381  |
# |specialty retailers other                     |2      |378  |
# |pharmaceuticals                               |0      |367  |
# |automotive                                    |2      |355  |
# |specialty retailers other                     |3      |351  |
# |financial services                            |3      |339  |
# |chemicals                                     |0      |334  |
# |minimuming crude oil production               |2      |323  |
# |automotive                                    |3      |320  |
# |insurance property and casualty stock         |3      |318  |
# |minimuming crude oil production               |3      |316  |
# |real estate                                   |2      |305  |
# |insurance property and casualty stock         |2      |301  |
# |minimuming                                    |3      |295  |
# |semiconductors and other electronic components|2      |276  |
# |semiconductors and other electronic components|3      |267  |
# |minimuming                                    |2      |267  |
# |internet services and retailing               |2      |266  |
# |insurance life health stock                   |2      |265  |
# |information technology services               |3      |264  |
# |telecommunications                            |0      |263  |
# |banking financial services                    |2      |261  |
# |utilities gas and electric                    |0      |254  |
# |banking financial services                    |3      |251  |
# |real estate                                   |3      |250  |
# |internet services and retailing               |3      |245  |
# |commercial banks                              |0      |244  |
# |wholesalers diversified                       |3      |240  |
# |pharmaceuticals                               |4      |230  |
# |insurance life health stock                   |3      |226  |
# |chemicals                                     |4      |226  |
# |diversified financials                        |2      |223  |
# |wholesalers diversified                       |2      |223  |
# |information technology services               |2      |222  |
# |insurance                                     |2      |222  |
# |insurance property and casualty stock         |0      |221  |
# |diversified financials                        |3      |220  |
# |specialty retailers other                     |0      |220  |
# |food consumer products                        |2      |219  |
# |financial services                            |0      |213  |
# |pipelines                                     |3      |207  |
# |pipelines                                     |2      |205  |
# |minimuming crude oil production               |0      |202  |
# |petroleum refining                            |3      |201  |
# |food consumer products                        |3      |199  |
# |industrial machinery                          |3      |195  |
# |automotive                                    |0      |192  |
# |motor vehicles parts                          |2      |190  |
# |real estate                                   |0      |187  |
# |automotive retailing services                 |2      |186  |
# |motor vehicles parts                          |3      |185  |
# |automotive retailing services                 |3      |184  |
# |insurance                                     |3      |183  |
# |packaging containers                          |2      |181  |
# |industrial machinery                          |2      |181  |
# |aerospace defense                             |2      |179  |
# |entertainment                                 |3      |177  |
# |securities                                    |2      |175  |
# |packaging containers                          |3      |174  |
# |securities                                    |3      |168  |
# |entertainment                                 |2      |167  |
# |commercial banks                              |4      |167  |
# |petroleum refining                            |2      |166  |
# |specialty retailers other                     |4      |165  |
# |insurance life health mutual                  |2      |163  |
# |insurance life health mutual                  |3      |163  |
# |minimuming                                    |0      |163  |
# |internet services and retailing               |0      |159  |
# |utilities gas and electric                    |4      |159  |
# |healthcare                                    |3      |158  |
# |general merchandisers                         |3      |156  |
# |financial data services                       |2      |155  |
# |food production                               |2      |155  |
# |healthcare                                    |2      |155  |
# |financial services                            |4      |152  |
# |energy                                        |3      |151  |
# |retail                                        |3      |151  |
# |telecommunications                            |4      |151  |
# |metals                                        |2      |151  |
# |semiconductors and other electronic components|0      |149  |
# |general merchandisers                         |2      |148  |
# |automotive                                    |4      |148  |
# |aerospace defense                             |3      |147  |
# |banking and financial services                |2      |146  |
# |airlines                                      |2      |146  |
# |financial data services                       |3      |146  |
# |insurance life health stock                   |0      |146  |
# |food services                                 |2      |145  |
# |banking financial services                    |0      |141  |
# |food services                                 |3      |141  |
# |energy                                        |2      |140  |
# |wholesalers diversified                       |0      |139  |
# |airlines                                      |3      |139  |
# |banking and financial services                |3      |138  |
# |banking                                       |3      |136  |
# |banking                                       |2      |135  |
# |food consumer products                        |0      |134  |
# |information technology services               |0      |133  |
# |computer software                             |3      |133  |
# |homebuilders                                  |2      |130  |
# |minimuming                                    |4      |129  |
# |beverages                                     |2      |129  |
# |insurance property and casualty stock         |4      |128  |
# |metals                                        |3      |127  |
# |motor vehicles parts                          |0      |127  |
# |pipelines                                     |0      |125  |
# |diversified financials                        |0      |124  |
# |financial services investment                 |2      |124  |
# |computer software                             |2      |120  |
# |computers office equipment                    |3      |120  |
# |real estate                                   |4      |120  |
# |energy oil gas experienceloration production  |3      |118  |
# |computers office equipment                    |2      |118  |
# |utilities                                     |3      |118  |
# |beverages                                     |3      |117  |
# |engineering construction                      |3      |117  |
# |insurance                                     |0      |117  |
# |retail                                        |2      |117  |
# |medical products and equipment                |2      |116  |
# |oil and gas                                   |3      |116  |
# |semiconductors and other electronic components|4      |116  |
# |food production                               |3      |115  |
# |minimuming crude oil production               |4      |114  |
# |specialty retailers apparel                   |2      |113  |
# |homebuilders                                  |3      |113  |
# |consumer goods                                |3      |112  |
# |information technology and services           |3      |111  |
# |consumer goods                                |2      |110  |
# |securities                                    |0      |110  |
# |oil and gas                                   |2      |110  |
# |financial services investment                 |3      |110  |
# |banking and financial services                |0      |109  |
# |specialty retailers apparel                   |3      |109  |
# |conglomerate                                  |3      |108  |
# |engineering construction                      |2      |108  |
# |food and drug stores                          |3      |107  |
# |information technology services               |4      |106  |
# |medical products and equipment                |3      |106  |
# |health care medical facilities                |3      |106  |
# |utilities                                     |2      |106  |
# |automotive retailing services                 |0      |105  |
# |health care insurance and managed care        |3      |104  |
# |food and beverage                             |2      |104  |
# |wholesalers food and grocery                  |3      |104  |
# |entertainment                                 |0      |102  |
# |diversified financials                        |4      |101  |
# |oil gas                                       |3      |101  |
# |health care insurance and managed care        |2      |101  |
# |industrial machinery                          |0      |100  |
# |electrical equipment                          |2      |99   |
# |internet services and retailing               |4      |99   |
# |packaging containers                          |0      |99   |
# |health care pharmacy and other services       |2      |98   |
# |oil gas                                       |2      |97   |
# |banking                                       |0      |97   |
# |information technology and services           |2      |97   |
# |wholesalers food and grocery                  |2      |96   |
# |food and drug stores                          |2      |96   |
# |conglomerate                                  |2      |95   |
# |pipelines                                     |4      |95   |
# |wholesalers health care                       |2      |95   |
# |insurance property and casualty mutual        |3      |94   |
# |wholesalers health care                       |3      |94   |
# |health care medical facilities                |2      |94   |
# |energy oil gas experienceloration production  |2      |93   |
# |automotive retailing services                 |4      |93   |
# |food and beverage                             |3      |92   |
# |diversified outsourcing services              |2      |92   |
# |transportation and logistics                  |3      |92   |
# |building materials glass                      |2      |91   |
# |airlines aviation                             |3      |91   |
# |e commerce technology                         |2      |91   |
# |transportation and logistics                  |2      |90   |
# |energy                                        |0      |89   |
# |wholesalers diversified                       |4      |89   |
# |food production                               |0      |89   |
# |building materials glass                      |3      |88   |
# |petroleum refining                            |0      |88   |
# |construction and farm machinery               |2      |86   |
# |industrial machinery                          |4      |86   |
# |healthcare                                    |0      |86   |
# |food services                                 |0      |85   |
# |insurance                                     |4      |84   |
# |securities                                    |4      |82   |
# |e commerce technology                         |3      |82   |
# |computers office equipment                    |0      |82   |
# |transportation and logistics                  |0      |82   |
# |insurance life health mutual                  |0      |82   |
# |diversified outsourcing services              |3      |82   |
# |construction and farm machinery               |3      |82   |
# |aerospace defense                             |0      |82   |
# |insurance property and casualty mutual        |2      |81   |
# |retail                                        |0      |80   |
# |health care pharmacy and other services       |3      |80   |
# |aerospace and defense                         |3      |80   |
# |motor vehicles parts                          |4      |79   |
# |home equipment furnishings                    |2      |79   |
# |financial data services                       |0      |79   |
# |apparel                                       |2      |79   |
# |engineering construction                      |0      |79   |
# |financial services investment                 |0      |78   |
# |airlines                                      |0      |78   |
# |home equipment furnishings                    |3      |78   |
# |distribution wholesale                        |2      |78   |
# |tobacco                                       |2      |77   |
# |metals                                        |0      |77   |
# |consumer goods                                |0      |76   |
# |network and other communications equipment    |2      |76   |
# |medical products and equipment                |0      |76   |
# |insurance life health stock                   |4      |75   |
# |specialty retailers apparel                   |0      |75   |
# |electrical equipment                          |3      |74   |
# |distribution wholesale                        |3      |73   |
# |electronics electrical equip                  |2      |73   |
# |wholesalers food and grocery                  |0      |73   |
# |hotels casinos resorts                        |2      |73   |
# |insurance life health mutual                  |4      |73   |
# |apparel                                       |3      |73   |
# |banking financial services                    |4      |72   |
# |travel and leisure cruises                    |3      |72   |
# |computer software                             |0      |71   |
# |information technology and services           |0      |71   |
# |aerospace and defense                         |2      |71   |
# |railroads                                     |2      |70   |
# |household and personal products               |2      |70   |
# |electronics electrical equip                  |3      |70   |
# |beverages                                     |0      |69   |
# |energy oil gas experienceloration production  |0      |69   |
# |real estate construction                      |2      |69   |
# |transportation logistics                      |3      |69   |
# |network and other communications equipment    |3      |68   |
# |packaging containers                          |4      |68   |
# |oil gas                                       |0      |68   |
# |airlines aviation                             |2      |68   |
# |electrical equipment                          |0      |68   |
# |energy utilities                              |3      |68   |
# |engineering industrial equipment              |2      |68   |
# |petroleum refining                            |4      |67   |
# |food production                               |4      |67   |
# |real estate construction                      |3      |66   |
# |entertainment                                 |4      |66   |
# |hotels casinos resorts                        |3      |66   |
# |general merchandisers                         |0      |66   |
# |tobacco                                       |3      |65   |
# |food consumer products                        |4      |65   |
# |trucking truck leasing                        |2      |65   |
# |homebuilders                                  |0      |65   |
# |utilities                                     |0      |65   |
# |electronics appliances                        |3      |65   |
# |wholesalers electronics and office equipment  |2      |65   |
# |health care insurance and managed care        |0      |65   |
# |conglomerate                                  |4      |65   |
# |household and personal products               |3      |65   |
# |health care pharmacy and other services       |0      |64   |
# |information technology                        |2      |63   |
# |general merchandisers                         |4      |63   |
# |engineering industrial equipment              |3      |63   |
# |transportation logistics                      |2      |63   |
# |travel and leisure cruises                    |2      |63   |
# |computer software                             |4      |62   |
# |oil and gas                                   |0      |62   |
# |metals                                        |4      |62   |
# |food and drug stores                          |0      |62   |
# |wholesalers health care                       |0      |62   |
# |energy                                        |4      |61   |
# |electronics appliances                        |2      |60   |
# |banking                                       |4      |60   |
# |real estate construction                      |0      |60   |
# |building materials glass                      |0      |59   |
# |utilities                                     |4      |58   |
# |real estate reit                              |3      |57   |
# |trucking truck leasing                        |3      |57   |
# |financial data services                       |4      |57   |
# |industrial manufacturing                      |3      |57   |
# |distribution wholesale                        |0      |57   |
# |medical products and equipment                |4      |56   |
# |retail                                        |4      |56   |
# |aerospace defense                             |4      |55   |
# |health care medical facilities                |4      |54   |
# |wholesalers electronics and office equipment  |3      |54   |
# |energy utilities                              |2      |53   |
# |aerospace and defense                         |0      |53   |
# |scientific photographic and control equipment |2      |52   |
# |real estate reit                              |2      |52   |
# |health care medical facilities                |0      |52   |
# |oil and gas                                   |4      |51   |
# |beverages                                     |4      |51   |
# |industrial conglomerate                       |3      |51   |
# |paints and coatings                           |3      |50   |
# |healthcare                                    |4      |50   |
# |media entertainment                           |3      |50   |
# |banking and financial services                |4      |50   |
# |retail food drug                              |3      |50   |
# |food manufacturing                            |2      |50   |
# |insurance property and casualty mutual        |0      |49   |
# |construction and farm machinery               |0      |49   |
# |tobacco                                       |0      |48   |
# |food services                                 |4      |48   |
# |industrial manufacturing                      |2      |48   |
# |steel                                         |3      |48   |
# |retail home improvement                       |3      |48   |
# |home equipment furnishings                    |0      |48   |
# |consumer goods                                |4      |48   |
# |travel and leisure cruises                    |0      |48   |
# |engineering construction                      |4      |47   |
# |construction engineering                      |2      |47   |
# |information technology                        |3      |47   |
# |hotels casinos resorts                        |0      |47   |
# |retail apparel                                |3      |47   |
# |travel and leisure hotels                     |2      |47   |
# |airlines                                      |4      |46   |
# |specialty retailers apparel                   |4      |46   |
# |airlines aviation                             |0      |45   |
# |technology entertainment                      |2      |45   |
# |consumer products cosmetics                   |3      |45   |
# |advertising marketing                         |3      |45   |
# |conglomerate                                  |0      |45   |
# |building materials glass                      |4      |45   |
# |railroads                                     |3      |45   |
# |food manufacturing                            |3      |45   |
# |apparel                                       |4      |44   |
# |real estate reit                              |0      |44   |
# |trucking truck leasing                        |0      |44   |
# |waste management                              |3      |44   |
# |technology entertainment                      |3      |44   |
# |food and beverage                             |0      |43   |
# |oil and gas equipment services                |2      |43   |
# |wholesalers health care                       |4      |43   |
# |apparel                                       |0      |42   |
# |construction engineering                      |3      |42   |
# |electronics electrical equip                  |0      |42   |
# |transportation and logistics                  |4      |42   |
# |retail apparel                                |2      |42   |
# |retail food drug                              |2      |42   |
# |transportation infrastructure                 |2      |42   |
# |tobacco                                       |4      |42   |
# |financial services investment                 |4      |41   |
# |technology                                    |2      |41   |
# |food and beverage                             |4      |41   |
# |advertising marketing                         |2      |41   |
# |energy oil gas experienceloration production  |4      |41   |
# |electrical equipment                          |4      |41   |
# |network and other communications equipment    |0      |41   |
# |e commerce technology                         |4      |41   |
# |information technology                        |0      |41   |
# |consumer products cosmetics                   |2      |41   |
# |logistics delivery services                   |2      |40   |
# |health care pharmacy and other services       |4      |40   |
# |paints and coatings                           |2      |40   |
# |insurance property and casualty mutual        |4      |40   |
# |distribution wholesale                        |4      |40   |
# |information technology and services           |4      |40   |
# |restaurants                                   |3      |40   |
# |electronics electrical equip                  |4      |40   |
# |cement and building materials                 |3      |40   |
# |industrial conglomerate                       |2      |39   |
# |hospitality hotels                            |3      |39   |
# |technology telecommunications                 |3      |39   |
# |travel and leisure hotels                     |3      |39   |
# |media and entertainment                       |2      |39   |
# |software                                      |3      |39   |
# |health care insurance and managed care        |4      |39   |
# |cement and building materials                 |2      |39   |
# |oil gas                                       |4      |38   |
# |hotels casinos resorts                        |4      |38   |
# |waste management                              |2      |38   |
# |technology telecommunications                 |2      |38   |
# |transportation infrastructure                 |3      |37   |
# |mail package and freight delivery             |3      |37   |
# |temporary help                                |2      |36   |
# |restaurants                                   |2      |36   |
# |manufacturing diversified                     |2      |36   |
# |steel                                         |2      |36   |
# |technology                                    |3      |36   |
# |wholesalers electronics and office equipment  |0      |35   |
# |manufacturing diversified                     |3      |35   |
# |railroads                                     |0      |35   |
# |diversified outsourcing services              |0      |35   |
# |scientific photographic and control equipment |3      |35   |
# |mail package and freight delivery             |2      |35   |
# |e commerce technology                         |0      |35   |
# |retail home improvement                       |2      |34   |
# |food manufacturing                            |0      |34   |
# |temporary help                                |3      |34   |
# |airlines aviation                             |4      |34   |
# |oil and gas equipment services                |3      |33   |
# |paints and coatings                           |0      |33   |
# |software                                      |2      |33   |
# |engineering industrial equipment              |0      |32   |
# |aerospace and defense                         |4      |31   |
# |industrial manufacturing                      |0      |31   |
# |network and other communications equipment    |4      |31   |
# |hospitality hotels                            |2      |31   |
# |wholesalers food and grocery                  |4      |31   |
# |cement and building materials                 |0      |31   |
# |logistics delivery services                   |0      |31   |
# |diversified outsourcing services              |4      |30   |
# |insurance property casualty                   |3      |30   |
# |computers office equipment                    |4      |30   |
# |homebuilders                                  |4      |30   |
# |consumer products cleaning products           |2      |30   |
# |household and personal products               |0      |30   |
# |transportation airlines                       |3      |29   |
# |home equipment furnishings                    |4      |29   |
# |transportation logistics                      |4      |29   |
# |media and entertainment                       |3      |29   |
# |diversified                                   |3      |29   |
# |logistics delivery services                   |3      |29   |
# |education                                     |2      |29   |
# |life sciences                                 |3      |29   |
# |electronics appliances                        |4      |29   |
# |media entertainment                           |2      |29   |
# |food manufacturing                            |4      |28   |
# |apparel fashion                               |2      |28   |
# |electronics appliances                        |0      |28   |
# |online recruitment                            |2      |28   |
# |apparel footwear                              |3      |28   |
# |personal care cosmetics                       |3      |27   |
# |hospitality hotels                            |0      |27   |
# |gas and energy                                |3      |26   |
# |construction and engineering                  |3      |26   |
# |internet technology                           |3      |26   |
# |ports and infrastructure                      |2      |26   |
# |temporary help                                |0      |26   |
# |personal care cosmetics                       |2      |26   |
# |equipment rental                              |3      |26   |
# |energy oil gas services                       |3      |26   |
# |energy utilities                              |0      |26   |
# |media and entertainment                       |0      |26   |
# |financial technology fintech                  |2      |26   |
# |real estate construction                      |4      |26   |
# |technology security                           |3      |26   |
# |retail food drug                              |0      |25   |
# |entertainment music streaminimumg             |3      |25   |
# |ports and infrastructure                      |3      |25   |
# |restaurants                                   |0      |25   |
# |food and drug stores                          |4      |25   |
# |business services testing compliance          |3      |25   |
# |equipment rental                              |2      |25   |
# |manufacturing steel                           |3      |25   |
# |technology telecommunications                 |0      |25   |
# |construction and farm machinery               |4      |25   |
# |equipment leasing                             |3      |24   |
# |advertising marketing                         |0      |24   |
# |transportation infrastructure                 |0      |24   |
# |business services pest control                |3      |24   |
# |entertainment streaminimumg services          |2      |24   |
# |oil and gas equipment services                |0      |24   |
# |construction engineering                      |0      |24   |
# |gambling gaminimumg                           |3      |24   |
# |entertainment music streaminimumg             |2      |24   |
# |financial services investment management      |3      |24   |
# |transportation logistics                      |0      |24   |
# |food and beverage alcoholic beverages         |3      |24   |
# |beverage                                      |3      |23   |
# |education                                     |3      |23   |
# |paints and coatings                           |4      |23   |
# |technology                                    |0      |23   |
# |retail apparel                                |0      |23   |
# |gambling                                      |3      |23   |
# |wholesalers electronics and office equipment  |4      |23   |
# |transportation airlines                       |2      |23   |
# |aviation airlines                             |3      |23   |
# |consumer products cosmetics                   |4      |23   |
# |cement and concrete                           |3      |22   |
# |construction                                  |3      |22   |
# |technology entertainment                      |0      |22   |
# |financial technology fintech                  |3      |22   |
# |retail general merchandise                    |3      |22   |
# |retail home improvement                       |0      |22   |
# |construction building materials               |2      |22   |
# |software                                      |0      |22   |
# |tire manufacturing                            |3      |22   |
# |real estate reit                              |4      |22   |
# |energy diversified                            |3      |22   |
# |retail books news                             |2      |22   |
# |retail books news                             |3      |22   |
# |electronics instrumentation                   |3      |22   |
# |retail electronics                            |2      |22   |
# |manufacturing diversified                     |0      |22   |
# |building materials construction               |3      |22   |
# |postal services                               |2      |22   |
# |food beverage                                 |2      |22   |
# |manufacturing electrical equipment            |2      |22   |
# |advertising and marketing                     |2      |21   |
# |retail home improvement                       |4      |21   |
# |jewelry and watches                           |2      |21   |
# |financial services investment banking         |2      |21   |
# |trucking truck leasing                        |4      |21   |
# |gaminimumg gambling                           |3      |21   |
# |building materials construction               |2      |21   |
# |retail apparel                                |4      |21   |
# |steel                                         |4      |21   |
# |jewelry and watches                           |3      |21   |
# |scientific photographic and control equipment |0      |21   |
# |retail farm and ranch supplies                |3      |21   |
# |retail general merchandise                    |2      |21   |
# |technology entertainment                      |4      |21   |
# |apparel and textiles                          |3      |20   |
# |electronics                                   |2      |20   |
# |energy oil gas services                       |2      |20   |
# |media entertainment                           |0      |20   |
# |aviation airlines                             |2      |20   |
# |information technology                        |4      |20   |
# |energy coal                                   |3      |20   |
# |technology social media                       |3      |20   |
# |life sciences                                 |2      |20   |
# |medical devices healthcare                    |3      |20   |
# |transportation rail                           |3      |20   |
# |industrial conglomerate                       |0      |20   |
# |technology ride hailing                       |2      |20   |
# |technology ride hailing                       |3      |20   |
# |insurance property casualty                   |2      |20   |
# |diversified                                   |2      |20   |
# |hospitality hotels                            |4      |20   |
# |advertising and marketing                     |3      |20   |
# |financial services insurance                  |3      |20   |
# |renewable energy                              |2      |20   |
# |aluminimumum and copper manufacturing         |2      |20   |
# |agrochemicals                                 |2      |20   |
# |mail package and freight delivery             |0      |19   |
# |retail discount department stores             |2      |19   |
# |lighting electronics                          |2      |19   |
# |industrial manufacturing                      |4      |19   |
# |hospitality entertainment                     |3      |19   |
# |electronics components                        |3      |19   |
# |tire manufacturing                            |2      |19   |
# |semiconductors                                |3      |19   |
# |hospitality entertainment                     |2      |19   |
# |business services data analytics              |3      |19   |
# |travel and leisure cruises                    |4      |19   |
# |energy utilities                              |4      |19   |
# |construction                                  |2      |19   |
# |online recruitment                            |3      |19   |
# |transportation infrastructure                 |4      |19   |
# |e commerce                                    |3      |19   |
# |medical devices healthcare                    |2      |19   |
# |lighting electronics                          |3      |19   |
# |food and beverage alcoholic beverages         |2      |19   |
# |retail discount department stores             |3      |19   |
# |electronics instrumentation                   |0      |18   |
# |gaminimumg gambling                           |2      |18   |
# |consumer products cleaning products           |3      |18   |
# |postal services                               |3      |18   |
# |cement and chemicals                          |3      |18   |
# |retail farm and ranch supplies                |2      |18   |
# |energy diversified                            |2      |18   |
# |apparel footwear                              |2      |18   |
# |financial services investment management      |2      |18   |
# |waste management                              |4      |18   |
# |transportation equipment                      |3      |18   |
# |agrochemicals                                 |3      |18   |
# |construction building materials               |3      |18   |
# |manufacturing transportation                  |3      |18   |
# |cloud software and services                   |3      |18   |
# |travel and leisure hotels                     |0      |18   |
# |electronics                                   |3      |18   |
# |apparel and textiles                          |2      |18   |
# |retail electronics                            |3      |18   |
# |advertising and marketing                     |0      |18   |
# |travel and leisure hotels                     |4      |18   |
# |manufacturing steel                           |2      |18   |
# |software technology                           |2      |18   |
# |logistics                                     |2      |18   |
# |waste management                              |0      |17   |
# |technology security                           |2      |17   |
# |beverage                                      |2      |17   |
# |manufacturing transportation                  |2      |17   |
# |mail package and freight delivery             |4      |17   |
# |publishing printing                           |3      |17   |
# |cement and chemicals                          |2      |17   |
# |logistics                                     |3      |17   |
# |internet technology                           |0      |17   |
# |technology social media                       |2      |17   |
# |engineering industrial equipment              |4      |17   |
# |transportation                                |3      |17   |
# |business services testing compliance          |2      |16   |
# |technology                                    |4      |16   |
# |aluminimumum and copper manufacturing         |3      |16   |
# |semiconductors                                |2      |16   |
# |media entertainment                           |4      |16   |
# |gas and energy                                |2      |16   |
# |cloud software and services                   |2      |16   |
# |technology search engines                     |2      |16   |
# |technology electronics                        |2      |16   |
# |equipment leasing                             |2      |16   |
# |transportation equipment                      |2      |16   |
# |building materials construction               |0      |16   |
# |business services testing compliance          |0      |16   |
# |construction and engineering                  |2      |16   |
# |manufacturing building systems                |2      |16   |
# |retail food drug                              |4      |16   |
# |household and personal products               |4      |16   |
# |technology search engines                     |3      |16   |
# |apparel fashion                               |3      |16   |
# |insurance property casualty                   |0      |15   |
# |consumer products cleaning products           |0      |15   |
# |renewable energy                              |0      |15   |
# |financial services investment banking         |3      |15   |
# |online recruitment                            |0      |15   |
# |equipment leasing                             |0      |15   |
# |renewable energy                              |3      |15   |
# |technology social media                       |0      |15   |
# |oil and gas equipment services                |4      |15   |
# |technology electronics                        |0      |15   |
# |transportation                                |4      |15   |
# |business services data analytics              |2      |15   |
# |electronics instrumentation                   |2      |15   |
# |forest and paper products                     |2      |15   |
# |steel                                         |0      |15   |
# |transportation rail                           |2      |15   |
# |personal care cosmetics                       |0      |15   |
# |food beverage                                 |3      |15   |
# |energy oil gas services                       |0      |15   |
# |cloud software and services                   |0      |15   |
# |cement and concrete                           |2      |15   |
# |media and entertainment                       |4      |14   |
# |entertainment satellite radio                 |2      |14   |
# |tire manufacturing                            |0      |14   |
# |entertainment satellite radio                 |0      |14   |
# |internet technology                           |2      |14   |
# |entertainment streaminimumg services          |0      |14   |
# |railroads                                     |4      |14   |
# |industrial conglomerate                       |4      |14   |
# |entertainment satellite radio                 |3      |14   |
# |lighting electronics                          |0      |14   |
# |aluminimumum and copper manufacturing         |0      |14   |
# |construction engineering                      |4      |14   |
# |electronics components                        |0      |14   |
# |electronics                                   |0      |14   |
# |financial services insurance                  |2      |14   |
# |gambling                                      |2      |14   |
# |technology electronics                        |3      |13   |
# |business services pest control                |2      |13   |
# |transportation                                |2      |13   |
# |postal services                               |4      |13   |
# |retail general merchandise                    |0      |13   |
# |aviation airlines                             |0      |13   |
# |manufacturing electrical equipment            |3      |13   |
# |gas and energy                                |0      |13   |
# |postal services                               |0      |13   |
# |consumer products cleaning products           |4      |13   |
# |medical devices healthcare                    |0      |13   |
# |construction building materials               |0      |13   |
# |e commerce                                    |2      |13   |
# |retail electronics                            |0      |13   |
# |jewelry and watches                           |0      |13   |
# |manufacturing building systems                |3      |13   |
# |education                                     |0      |13   |
# |logistics delivery services                   |4      |13   |
# |food beverage                                 |0      |13   |
# |financial technology fintech                  |0      |12   |
# |ports and infrastructure                      |4      |12   |
# |financial services investment management      |0      |12   |
# |gambling                                      |0      |12   |
# |software                                      |4      |12   |
# |business services testing compliance          |4      |12   |
# |transportation equipment                      |0      |12   |
# |construction building materials               |4      |12   |
# |equipment rental                              |0      |12   |
# |financial services investment banking         |4      |12   |
# |agrochemicals                                 |0      |12   |
# |transportation                                |0      |12   |
# |business services data analytics              |0      |12   |
# |transportation airlines                       |0      |12   |
# |consumer products cosmetics                   |0      |12   |
# |retail discount department stores             |0      |12   |
# |forest and paper products                     |3      |12   |
# |food and beverage alcoholic beverages         |0      |12   |
# |temporary help                                |4      |12   |
# |gambling gaminimumg                           |2      |11   |
# |technology search engines                     |4      |11   |
# |transportation rail                           |0      |11   |
# |publishing printing                           |2      |11   |
# |apparel and textiles                          |0      |11   |
# |semiconductors                                |0      |11   |
# |energy coal                                   |2      |11   |
# |cement and building materials                 |4      |11   |
# |retail farm and ranch supplies                |0      |11   |
# |logistics                                     |4      |11   |
# |apparel footwear                              |0      |11   |
# |advertising marketing                         |4      |11   |
# |construction and engineering                  |4      |11   |
# |diversified                                   |0      |11   |
# |cloud software and services                   |4      |11   |
# |apparel fashion                               |0      |11   |
# |electronics components                        |2      |11   |
# |aluminimumum and copper manufacturing         |4      |10   |
# |manufacturing electrical equipment            |0      |10   |
# |technology telecommunications                 |4      |10   |
# |technology security                           |0      |10   |
# |software technology                           |4      |10   |
# |forest and paper products                     |0      |10   |
# |financial services investment banking         |0      |10   |
# |technology search engines                     |0      |10   |
# |software technology                           |3      |10   |
# |entertainment streaminimumg services          |3      |10   |
# |cement and chemicals                          |4      |10   |
# |energy coal                                   |4      |10   |
# |agrochemicals                                 |4      |10   |
# |medical devices healthcare                    |4      |10   |
# |publishing printing                           |0      |10   |
# |scientific photographic and control equipment |4      |10   |
# |retail electronics                            |4      |10   |
# |gambling gaminimumg                           |0      |10   |
# |construction                                  |4      |9    |
# |manufacturing building systems                |0      |9    |
# |logistics                                     |0      |9    |
# |construction and engineering                  |0      |9    |
# |energy diversified                            |0      |9    |
# |manufacturing diversified                     |4      |9    |
# |manufacturing building systems                |4      |9    |
# |manufacturing steel                           |0      |9    |
# |apparel footwear                              |4      |9    |
# |financial services insurance                  |4      |9    |
# |business services pest control                |0      |9    |
# |transportation airlines                       |4      |8    |
# |restaurants                                   |4      |8    |
# |gaminimumg gambling                           |0      |8    |
# |life sciences                                 |4      |8    |
# |publishing printing                           |4      |8    |
# |retail farm and ranch supplies                |4      |8    |
# |financial services insurance                  |0      |8    |
# |entertainment streaminimumg services          |4      |8    |
# |gaminimumg gambling                           |4      |8    |
# |life sciences                                 |0      |8    |
# |beverage                                      |0      |8    |
# |food beverage                                 |4      |8    |
# |electronics instrumentation                   |4      |8    |
# |cement and concrete                           |0      |8    |
# |equipment leasing                             |4      |8    |
# |entertainment music streaminimumg             |4      |8    |
# |retail general merchandise                    |4      |8    |
# |education                                     |4      |8    |
# |hospitality entertainment                     |4      |8    |
# |business services pest control                |4      |8    |
# |gambling                                      |4      |8    |
# |forest and paper products                     |4      |7    |
# |cement and chemicals                          |0      |7    |
# |e commerce                                    |4      |7    |
# |transportation equipment                      |4      |7    |
# |entertainment music streaminimumg             |0      |7    |
# |manufacturing transportation                  |0      |7    |
# |gambling gaminimumg                           |4      |7    |
# |diversified                                   |4      |7    |
# |building materials construction               |4      |7    |
# |retail books news                             |0      |7    |
# |software technology                           |0      |7    |
# |construction                                  |0      |7    |
# |insurance property casualty                   |4      |7    |
# |technology electronics                        |4      |7    |
# |manufacturing transportation                  |4      |7    |
# |tire manufacturing                            |4      |7    |
# |advertising and marketing                     |4      |7    |
# |internet technology                           |4      |6    |
# |business services data analytics              |4      |6    |
# |energy oil gas services                       |4      |6    |
# |energy diversified                            |4      |6    |
# |semiconductors                                |4      |6    |
# |retail discount department stores             |4      |6    |
# |manufacturing steel                           |4      |6    |
# |ports and infrastructure                      |0      |6    |
# |online recruitment                            |4      |6    |
# |electronics components                        |4      |6    |
# |jewelry and watches                           |4      |6    |
# |technology ride hailing                       |0      |6    |
# |e commerce                                    |0      |6    |
# |cement and concrete                           |4      |6    |
# |apparel fashion                               |4      |6    |
# |entertainment satellite radio                 |4      |5    |
# |transportation rail                           |4      |5    |
# |electronics                                   |4      |5    |
# |food and beverage alcoholic beverages         |4      |5    |
# |technology ride hailing                       |4      |5    |
# |retail books news                             |4      |5    |
# |manufacturing electrical equipment            |4      |5    |
# |hospitality entertainment                     |0      |5    |
# |aviation airlines                             |4      |5    |
# |energy coal                                   |0      |5    |
# |technology social media                       |4      |5    |
# |financial technology fintech                  |4      |5    |
# |gas and energy                                |4      |5    |
# |technology security                           |4      |4    |
# |renewable energy                              |4      |4    |
# |financial services investment management      |4      |4    |
# |equipment rental                              |4      |4    |
# |lighting electronics                          |4      |4    |
# |personal care cosmetics                       |4      |3    |
# |apparel and textiles                          |4      |2    |
# +----------------------------------------------+-------+-----+

# %%
# """ """ # Export Processed Data :save the clustered data to a CSV file for further analysis or visualization.""" 
# clustered_data.show(1, truncate=False)

# output_path = "file:///home/ubuntu/Project_Code/skills_demand_analysis_results"
# clustered_data.write.csv(output_path, header=True)

# print(f"Processed data saved to {output_path}") """

# Select only the relevant columns and convert arrays to strings if needed
# Select only the relevant columns
# !hdfs dfs -rm -r /user/ubuntu/skills_demand_analysis_results

export_df = clustered_data.select(
    "job_description", 
    "job_skills", 
    "job_industry", 
    "job_location", 
    "experience_level", 
    "min_salary", 
    "max_salary",
    "cluster"
)

# Convert DataFrame to RDD and format as CSV strings
header = ','.join(export_df.columns)
data_rdd = export_df.rdd.map(lambda row: ','.join(f'"{str(val)}"' if val is not None else '""' for val in row))

# Combine header and data using sparkContext
final_rdd = spark.sparkContext.parallelize([header]).union(data_rdd)

# Save as a single text file
output_path = "hdfs://namenode:9000/user/ubuntu/skills_demand_analysis_results"
final_rdd.coalesce(1).saveAsTextFile(output_path)

print(f"Processed data saved to {output_path}")

# Optional: If you want to get the file locally after saving to HDFS
from subprocess import call
local_path = "/home/ubuntu/skills_demand_analysis_results.csv"
call(["hdfs", "dfs", "-getmerge", output_path, local_path])
# Out:
# Deleted /user/ubuntu/skills_demand_analysis_results
# Processed data saved to hdfs://namenode:9000/user/ubuntu/skills_demand_analysis_results
# 2024-11-20 11:36:22,727 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2024-11-20 11:36:24,840 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2024-11-20 11:36:25,778 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 0
